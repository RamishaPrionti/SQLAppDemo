# %%
pip install pandas sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: pandas in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (2.3.3)
# Requirement already satisfied: sqlalchemy in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (2.0.44)
# Requirement already satisfied: psycopg2-binary in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (2.9.11)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\preon\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine, text

DB_URL = "postgresql://rp_mini_project2_db_user:U19DegnNWLaUCDSx03KNO4TB6JQYDefE@dpg-d4ni44qdbo4c73fieseg-a.ohio-postgres.render.com/rp_mini_project2_db"

engine = create_engine(DB_URL)

try:
    with engine.connect() as conn:
        print("✅ Connected to Render!")
        df = pd.read_sql(text("SELECT * FROM customer LIMIT 5;"), conn)

    print(f"rows returned: {len(df)}")
    df  # this should display the table

except Exception as e:
    print("❌ Error:", e)
# Out:
# ✅ Connected to Render!
# rows returned: 3
